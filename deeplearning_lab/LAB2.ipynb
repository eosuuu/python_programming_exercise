# %%
import tensorflow as tf

x_train = [1,2,3]
y_train = [1,2,3]

W = tf.Variable(tf.random_normal([1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

hypothis = x_train * W + b

cost = tf.reduce_mean(tf.square(hypothis-y_train))

optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 0.14026535 [0.9464583] [0.4790434]
# 20 0.024145402 [0.83600104] [0.406833]
# 40 0.020993127 [0.8329511] [0.38298118]
# 60 0.019057812 [0.83977747] [0.3645319]
# 80 0.017308546 [0.8472099] [0.34735733]
# 100 0.015719885 [0.85438114] [0.33102873]
# 120 0.0142770605 [0.86122376] [0.31547123]
# 140 0.01296667 [0.86774576] [0.3006452]
# 160 0.011776525 [0.87396115] [0.28651595]
# 180 0.010695622 [0.87988454] [0.27305079]
# 200 0.009713942 [0.88552946] [0.2602184]
# 220 0.008822347 [0.8909092] [0.24798909]
# 240 0.008012606 [0.896036] [0.23633449]
# 260 0.0072771795 [0.900922] [0.22522765]
# 280 0.006609248 [0.9055783] [0.21464276]
# 300 0.006002618 [0.9100158] [0.2045553]
# 320 0.0054516713 [0.9142447] [0.19494194]
# 340 0.0049512987 [0.9182748] [0.1857804]
# 360 0.0044968533 [0.9221157] [0.17704943]
# 380 0.004084107 [0.92577595] [0.16872874]
# 400 0.0037092566 [0.9292642] [0.16079913]
# 420 0.0033688105 [0.9325885] [0.15324219]
# 440 0.003059606 [0.93575656] [0.14604037]
# ...

# %%
import tensorflow as tf

# x_train = [1,2,3]
# y_train = [1,2,3]

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)


W = tf.Variable(tf.random_normal([1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

hypothis = x_train * W + b

cost = tf.reduce_mean(tf.square(hypothis-y_train))

optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict={X:[1,2,3], Y:[1,2,3]})
#     sess.run(train)
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 0.36321163 [0.83802754] [-0.19560258]
# 20 0.0047001042 [1.0238917] [-0.10799656]
# 40 0.0013204402 [1.039742] [-0.09545468]
# 60 0.0011725127 [1.0394903] [-0.0902577]
# 80 0.001064652 [1.0377885] [-0.08594822]
# 100 0.00096693676 [1.0360271] [-0.08190255]
# 120 0.000878185 [1.0343354] [-0.07805281]
# 140 0.0007975868 [1.0327219] [-0.07438456]
# 160 0.00072437874 [1.0311842] [-0.07088875]
# 180 0.00065789 [1.0297185] [-0.06755731]
# 200 0.0005975084 [1.0283219] [-0.06438235]
# 220 0.0005426685 [1.0269908] [-0.06135659]
# 240 0.00049285433 [1.0257224] [-0.05847302]
# 260 0.00044762206 [1.0245135] [-0.05572498]
# 280 0.0004065352 [1.0233616] [-0.05310611]
# 300 0.0003692247 [1.0222638] [-0.05061039]
# 320 0.00033533652 [1.0212175] [-0.04823199]
# 340 0.00030455473 [1.0202199] [-0.04596518]
# 360 0.0002766015 [1.0192697] [-0.04380477]
# 380 0.0002512109 [1.0183641] [-0.04174604]
# 400 0.00022815359 [1.0175011] [-0.0397841]
# 420 0.00020721136 [1.0166786] [-0.03791438]
# ...

# %%
import tensorflow as tf

# x_train = [1,2,3]
# y_train = [1,2,3]

X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])


W = tf.Variable(tf.random_normal([1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

hypothis = X * W + b

cost = tf.reduce_mean(tf.square(hypothis-Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict={X:[1,2,3,4,5], Y:[2.1,3.1,4.1,5.1,6.1]})
#     sess.run(train)
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)

print(sess.run(hypothis, feed_dict={X:[5]}))
print(sess.run(hypothis, feed_dict={X:[2.5]}))
print(sess.run(hypothis, feed_dict={X:[1.5,3.5]}))
# Out:
# 0 85.74558 [-1.0878925] [0.94020045]
# 20 0.025927585 [0.89044493] [1.4607598]
# 40 0.021115594 [0.9059378] [1.4394372]
# 60 0.018440394 [0.91213554] [1.4172179]
# 80 0.01610414 [0.91788995] [1.3964431]
# 100 0.014063889 [0.9232674] [1.377029]
# 120 0.0122820875 [0.92829263] [1.3588861]
# 140 0.010726069 [0.9329888] [1.3419315]
# 160 0.009367129 [0.93737745] [1.326087]
# 180 0.008180383 [0.9414787] [1.3112803]
# 200 0.007143973 [0.9453114] [1.2974432]
# 220 0.00623889 [0.948893] [1.2845124]
# 240 0.0054484545 [0.95224005] [1.2724284]
# 260 0.004758154 [0.955368] [1.2611357]
# 280 0.0041553364 [0.95829093] [1.2505828]
# 300 0.0036288765 [0.96102256] [1.2407207]
# 320 0.003169135 [0.96357524] [1.2315049]
# 340 0.002767617 [0.9659607] [1.2228925]
# 360 0.002416982 [0.96818995] [1.2148442]
# 380 0.0021107763 [0.9702732] [1.2073232]
# 400 0.0018433456 [0.97222006] [1.2002943]
# 420 0.0016098085 [0.9740394] [1.193726]
# 440 0.0014058589 [0.97573954] [1.1875879]
# ...

# %%
x_train = [1,2,3]
y_train = [1,2,3]

W = tf.Variable(tf.random.normal([1]), name="weight")
b = tf.Variable(tf.random.normal([1]), name="bias")

hypo = x_train * W + b

cost = tf.reduce_mean(tf.square(hypo - y_train))

optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 0.6656736 [0.5026323] [0.28709337]
# 20 0.029209562 [0.7927002] [0.39091995]
# 40 0.021311909 [0.8278369] [0.38371918]
# 60 0.019308532 [0.8383459] [0.36674958]
# 80 0.017535875 [0.8461733] [0.34961492]
# 100 0.015926352 [0.85342455] [0.33319396]
# 120 0.014464565 [0.8603151] [0.31753603]
# 140 0.013136956 [0.86688] [0.30261308]
# 160 0.011931186 [0.87313616] [0.28839132]
# 180 0.010836092 [0.87909836] [0.2748379]
# 200 0.009841524 [0.8847803] [0.26192153]
# 220 0.008938222 [0.8901952] [0.24961218]
# 240 0.008117828 [0.89535564] [0.23788133]
# 260 0.0073727514 [0.9002735] [0.2267018]
# 280 0.0066960356 [0.9049603] [0.21604766]
# 300 0.006081457 [0.90942675] [0.20589423]
# 320 0.0055232793 [0.91368335] [0.19621797]
# 340 0.0050163255 [0.91774] [0.18699643]
# 360 0.004555901 [0.9216059] [0.17820825]
# 380 0.0041377484 [0.9252901] [0.16983312]
# 400 0.0037579716 [0.9288011] [0.16185164]
# 420 0.0034130532 [0.93214726] [0.15424521]
# 440 0.0030997877 [0.9353361] [0.14699626]
# ...
