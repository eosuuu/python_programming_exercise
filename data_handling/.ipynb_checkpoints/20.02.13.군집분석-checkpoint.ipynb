# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

from sklearn.cluster import KMeans, DBSCAN
# Out:
# /home/pirl/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/pirl/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df = pd.read_csv("직무능력평가.csv", engine='python')

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
df_scaled[:5]
# Out:
# array([[-1.8076031 , -1.19166169, -1.92300586, -1.50494461, -0.35542617,
#          1.77141034,  0.20430138],
#        [-0.13647543, -0.19861028, -0.17733772, -0.20508842, -0.15977874,
#         -0.18159526,  0.4020124 ],
#        [ 0.53197564,  0.25972114,  1.23582221,  1.09476777,  1.11192959,
#          1.15467173,  0.50086791],
#        [-0.30358819, -0.27499885, -0.67610004, -0.81168798, -1.0401922 ,
#          0.9490922 , -0.78425369],
#        [ 1.36753948,  0.87082969,  0.23829756,  0.83479653,  0.622811  ,
#          0.84630243,  0.4020124 ]])

# %%
df_y = df_scaled[:,0]
df_x = df_scaled[:,1::]

# %%
Z_ward = linkage(df_x, method='ward', metric='euclidean')
Z_average = linkage(df_x, method='average', metric='euclidean')
Z_minkowski = linkage(df_x, method='average', metric='minkowski')

plt.figure(figsize=(10,10))
ax = plt.subplot(111)
dendrogram(Z_ward, leaf_font_size=10, orientation='right')
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("distance")
plt.ylabel("sample index")
# Out:
# Text(0, 0.5, 'sample index')

# %%
plt.figure(figsize=(10,10))
ax = plt.subplot(111)
dendrogram(Z_average, leaf_font_size=10, orientation='right')
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("distance")
plt.ylabel("sample index")
# Out:
# Text(0, 0.5, 'sample index')

# %%
plt.figure(figsize=(10,10))
ax = plt.subplot(111)
dendrogram(Z_minkowski, leaf_font_size=10, orientation='right')
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("distance")
plt.ylabel("sample index")
# Out:
# Text(0, 0.5, 'sample index')

# %%
cluster_hierarchical = fcluster(Z=Z_ward, t=5, criterion='distance')
df["clusterhierarchical"] = cluster_hierarchical
df.head()
# Out:
#    EVAL  DISSATIS  PRIVILEGE  CHANCE  ADVANCE  CRITISM  PROMOTION  \
# 0    43        51         30      39       61       92         45
# 1    63        64         51      54       63       73         47
# 2    71        70         68      69       76       86         48
# 3    61        63         45      47       54       84         35
# 4    81        78         56      66       71       83         47
#
#    clusterhierarchical
# 0                    1
# 1                    5
# 2                    3
# 3                    1
# 4                    3

# %%
ds_summary_hc = df.groupby("clusterhierarchical").agg(['min','mean', 'max'])
level0 = ds_summary_hc.columns.get_level_values(0)
level1 = ds_summary_hc.columns.get_level_values(1)
ds_summary_hc.columns = level0 + "_" + level1
ds_summary_hc.reset_index(inplace=True)
ds_summary_hc.round(3)
# Out:
#    clusterhierarchical  EVAL_min  EVAL_mean  EVAL_max  DISSATIS_min  \
# 0                    1        43     57.429        67            51
# 1                    2        40     53.200        69            37
# 2                    3        50     71.889        85            58
# 3                    4        68     70.000        72            82
# 4                    5        58     69.143        82            61
#
#    DISSATIS_mean  DISSATIS_max  PRIVILEGE_min  PRIVILEGE_mean  PRIVILEGE_max  \
# 0         58.857            66             30          43.571             52
# 1         49.400            62             33          46.800             57
# 2         73.889            85             54          63.333             71
# 3         82.500            83             72          77.500             83
# 4         72.714            90             39          47.143             52
#
#    ...  CRITISM_max  PROMOTION_min  PROMOTION_mean  PROMOTION_max  \
# 0  ...           92             33          38.571             45
# 1  ...           67             25          35.000             49
# 2  ...           86             46          54.667             72
# 3  ...           83             31          33.000             35
# 4  ...           85             35          40.714             47
#
#    CluserKmeans_min  CluserKmeans_mean  CluserKmeans_max  ClusterKmeans_min  \
# 0                 1              1.000                 1                  1
# 1                 4              4.000                 4                  3
# 2                 2              2.333                 5                  2
# 3                 3              3.000                 3                  2
# 4                 5              5.000                 5                  2
#
#    ClusterKmeans_mean  ClusterKmeans_max
# 0               1.000                  1
# 1               3.800                  4
# 2               3.000                  5
# 3               2.000                  2
# 4               2.857                  3
#
# [5 rows x 28 columns]

# %%
n_iter_cluster = 15
cluster_range = [i+1 for i in range(n_iter_cluster)]
clus_error = []
for v_n_clus in cluster_range:
    clus = KMeans(v_n_clus)
    clus.fit(df_x)
    clus_error.append(clus.inertia_)
    
ds_error = pd.DataFrame({"NumberofCluster":cluster_range, "Error":clus_error})
ds_error
# Out:
#     NumberofCluster       Error
# 0                 1  180.000000
# 1                 2  114.082503
# 2                 3   93.636837
# 3                 4   79.567709
# 4                 5   67.415873
# 5                 6   58.348212
# 6                 7   49.793926
# 7                 8   43.165914
# 8                 9   40.750608
# 9                10   32.793639
# 10               11   31.416726
# 11               12   26.172635
# 12               13   22.069254
# 13               14   18.785041
# 14               15   16.545068

# %%
plt.figure(figsize=(10,10))
plt.plot(ds_error['NumberofCluster'], ds_error['Error'])
plt.title("Sum of squared distance")
plt.xlabel("Clusters")
plt.ylabel("Sum of squared distance")
# Out:
# Text(0, 0.5, 'Sum of squared distance')

# %%
clus = KMeans(5)
clus.fit(df_x)
cluster_kmeans = [i+1 for i in clus.labels_]
df['ClusterKmeans'] = cluster_kmeans
df.head()
# Out:
#    EVAL  DISSATIS  PRIVILEGE  CHANCE  ADVANCE  CRITISM  PROMOTION  \
# 0    43        51         30      39       61       92         45
# 1    63        64         51      54       63       73         47
# 2    71        70         68      69       76       86         48
# 3    61        63         45      47       54       84         35
# 4    81        78         56      66       71       83         47
#
#    clusterhierarchical  CluserKmeans  ClusterKmeans
# 0                    1             1              1
# 1                    5             5              3
# 2                    3             2              2
# 3                    1             1              1
# 4                    3             2              2

# %%
ds_summary_km = df.drop("clusterhierarchical", axis=1, inplace=False).groupby("ClusterKmeans").agg(['min','mean','max'])
level0 = ds_summary_km.columns.get_level_values(0)
level1 = ds_summary_km.columns.get_level_values(1)
ds_summary_km.columns = level0 + "_" + level1
ds_summary_km.reset_index(inplace=True)
ds_summary_km.round(3)
# Out:
#    ClusterKmeans  EVAL_min  EVAL_mean  EVAL_max  DISSATIS_min  DISSATIS_mean  \
# 0              1        43     57.429        67            51         58.857
# 1              2        50     69.667        81            58         72.556
# 2              3        58     69.000        82            53         70.286
# 3              4        40     50.500        69            37         48.500
# 4              5        66     75.000        85            77         82.333
#
#    DISSATIS_max  PRIVILEGE_min  PRIVILEGE_mean  PRIVILEGE_max  ...  \
# 0            66             30          43.571             52  ...
# 1            83             46          63.333             83  ...
# 2            90             39          48.143             53  ...
# 3            62             33          45.250             57  ...
# 4            85             64          67.000             71  ...
#
#    ADVANCE_max  CRITISM_min  CRITISM_mean  CRITISM_max  PROMOTION_min  \
# 0           66           74        81.143           92             33
# 1           80           77        80.778           86             31
# 2           70           54        69.429           80             34
# 3           55           49        58.250           64             25
# 4           88           74        76.333           79             55
#
#    PROMOTION_mean  PROMOTION_max  CluserKmeans_min  CluserKmeans_mean  \
# 0          38.571             45                 1              1.000
# 1          46.000             60                 2              2.889
# 2          39.000             47                 4              4.857
# 3          35.250             49                 4              4.000
# 4          63.333             72                 2              2.000
#
#    CluserKmeans_max
# 0                 1
# 1                 5
# 2                 5
# 3                 4
# 4                 2
#
# [5 rows x 25 columns]

# %%
X = df['DISSATIS']
Y = df['CHANCE']

markers = ['o','v', '^','s','<','>','p','D']
para_eps = [k/10 for k in range(10,16,1)]
para_min_sample = [2,3,4,5]
fig, axes = plt.subplots(len(para_eps), len(para_min_sample), figsize=(15,15))
fig.tight_layout(w_pad=1, h_pad=3)
for i,eps in enumerate(para_eps):
    for j,min_sample in enumerate(para_min_sample):
        dbscan = DBSCAN(min_samples=min_sample, eps=eps)
        clusters = dbscan.fit_predict(df_x)
        clusters = clusters+1
        for(n_clus, clus) in enumerate(range(min(clusters), max(clusters)+1, 1)):
            axes[i,j].scatter(X[clusters==clus], Y[clusters==clus], marker=markers[n_clus], s=100)
            axes[i,j].set_title("eps =" + str(eps) + ", min_sample=" + str(min_sample) + \
                                "\n # of cluser = " + str(max(clusters)), fontsize=15)

# %%
dbscan = DBSCAN(eps=1.4, min_samples=2).fit(df_x)
cluster_dbscan = dbscan.labels_
for(i, val) in enumerate(cluster_dbscan):
    if val<0:
        cluster_dbscan[i] = 0
    else:
        cluster_dbscan[i] = cluster_dbscan[i] + 1
df['ClusterDBScan'] = cluster_dbscan
df.head()
# Out:
#    EVAL  DISSATIS  PRIVILEGE  CHANCE  ADVANCE  CRITISM  PROMOTION  \
# 0    43        51         30      39       61       92         45
# 1    63        64         51      54       63       73         47
# 2    71        70         68      69       76       86         48
# 3    61        63         45      47       54       84         35
# 4    81        78         56      66       71       83         47
#
#    clusterhierarchical  CluserKmeans  ClusterKmeans  ClusterDBScan
# 0                    1             1              1              0
# 1                    5             5              3              1
# 2                    3             2              2              2
# 3                    1             1              1              1
# 4                    3             2              2              2

# %%
ds_summary_db = df.drop(["clusterhierarchical", 'ClusterKmeans'], axis=1, inplace=False).groupby("ClusterDBScan").agg(['min','mean','max'])
level0 = ds_summary_db.columns.get_level_values(0)
level1 = ds_summary_db.columns.get_level_values(1)
ds_summary_db.columns = level0 + "_" + level1
ds_summary_db.reset_index(inplace=True)
ds_summary_db.round(3)
# Out:
#    ClusterDBScan  EVAL_min  EVAL_mean  EVAL_max  DISSATIS_min  DISSATIS_mean  \
# 0              0        40      61.00        82            37         63.846
# 1              1        48      60.75        67            54         60.750
# 2              2        65      74.40        81            70         74.000
# 3              3        58      64.50        71            67         71.000
# 4              4        74      79.50        85            85         85.000
#
#    DISSATIS_max  PRIVILEGE_min  PRIVILEGE_mean  PRIVILEGE_max  ...  \
# 0            90             30          54.385             83  ...
# 1            66             42          47.250             52  ...
# 2            78             46          56.400             68  ...
# 3            75             42          46.000             50  ...
# 4            85             64          67.500             71  ...
#
#    ADVANCE_max  CRITISM_min  CRITISM_mean  CRITISM_max  PROMOTION_min  \
# 0           88           49        70.615           92             25
# 1           66           73        78.625           84             33
# 2           80           77        81.800           86             46
# 3           70           66        67.000           68             35
# 4           79           74        76.500           79             55
#
#    PROMOTION_mean  PROMOTION_max  CluserKmeans_min  CluserKmeans_mean  \
# 0          41.923             72                 1              3.538
# 1          39.125             47                 1              2.000
# 2          47.200             49                 2              2.600
# 3          38.000             41                 5              5.000
# 4          59.000             63                 2              2.000
#
#    CluserKmeans_max
# 0                 5
# 1                 5
# 2                 5
# 3                 5
# 4                 2
#
# [5 rows x 25 columns]
